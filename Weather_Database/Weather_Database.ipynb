# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time
import requests

from citipy import citipy
from config import weather_api_key
from datetime import datetime

# %%
#create set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add latitudes and longitudes to a list 
coordinates = list(lat_lngs)

# %%
# create a list for holding the cities
cities = []
# identify nearest city for each lat and long combo 
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #if the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
#print the city to confirm sufficient count
len(cities)
# Out:
# 733

# %%
#access URL
#starting URL for weather API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_weather = requests.get(url).json()

# %%
# List of city data
city_data = []
# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")
# Create counters
record_count = 1
set_count = 1
# Loop through all the cities in our list
for i, city in enumerate(cities):
   # Group cities in sets of 50 for logging purposes
   if (i % 50 == 0 and i >= 50):
       set_count += 1
       record_count = 1
   # Create endpoint URL with each city
   city_url = url + "&q=" + city.replace(" ", "+")
   # Log the url, record, and set numbers
   print(f"Processing Record {record_count} of Set {set_count} | {city}")
   # Add 1 to the record count
   record_count += 1
   # Run an API request for each of the cities
   try:
       # Parse the JSON and retrieve data
       city_weather = requests.get(city_url).json()
       # Parse out the max temp, humidity, and cloudiness
       city_lat = city_weather["coord"]["lat"]
       city_lng = city_weather["coord"]["lon"]
       city_max_temp = city_weather["main"]["temp_max"]
       city_humidity = city_weather["main"]["humidity"]
       city_clouds = city_weather["clouds"]["all"]
       city_wind = city_weather["wind"]["speed"]
       city_country = city_weather["sys"]["country"]
       city_description = city_weather["weather"][0]["description"] 
        
       # Append the City information into city_data list
       city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description": city_description})
   # If an error is experienced, skip the city
   except:
       print("City not found. Skipping...")
       pass
# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | solnechnyy
# Processing Record 4 of Set 1 | castro
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | saint-augustin
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | sao filipe
# Processing Record 10 of Set 1 | guozhen
# Processing Record 11 of Set 1 | meulaboh
# Processing Record 12 of Set 1 | goianira
# Processing Record 13 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 14 of Set 1 | lages
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | saint george
# Processing Record 18 of Set 1 | vila velha
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | lompoc
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | bilibino
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | kenai
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | college
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | noumea
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | sao lourenco do oeste
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | nome
# Processing Record 33 of Set 1 | talnakh
# Processing Record 34 of Set 1 | gariadhar
# Processing Record 35 of Set 1 | jamestown
# Processing Record 36 of Set 1 | tantoyuca
# Processing Record 37 of Set 1 | kapaa
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | tokmak
# Processing Record 41 of Set 1 | avera
# Processing Record 42 of Set 1 | riyadh
# Processing Record 43 of Set 1 | bredasdorp
# Processing Record 44 of Set 1 | itacare
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | sur
# Processing Record 47 of Set 1 | hithadhoo
# Processing Record 48 of Set 1 | gualaquiza
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | phirangipuram
# Processing Record 2 of Set 2 | semenivka
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | pangkalanbuun
# Processing Record 5 of Set 2 | hobart
# Processing Record 6 of Set 2 | saskylakh
# Processing Record 7 of Set 2 | mar del plata
# Processing Record 8 of Set 2 | port victoria
# Processing Record 9 of Set 2 | kurmanayevka
# Processing Record 10 of Set 2 | punta arenas
# Processing Record 11 of Set 2 | aripuana
# Processing Record 12 of Set 2 | cabo san lucas
# Processing Record 13 of Set 2 | mujiayingzi
# Processing Record 14 of Set 2 | namatanai
# Processing Record 15 of Set 2 | vilyuysk
# Processing Record 16 of Set 2 | lebu
# Processing Record 17 of Set 2 | buraydah
# Processing Record 18 of Set 2 | atar
# Processing Record 19 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 2 | portobelo
# Processing Record 21 of Set 2 | balaipungut
# Processing Record 22 of Set 2 | nizhniy tsasuchey
# Processing Record 23 of Set 2 | baiao
# Processing Record 24 of Set 2 | dikson
# Processing Record 25 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 2 | thompson
# Processing Record 28 of Set 2 | pangody
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | coihaique
# Processing Record 31 of Set 2 | hasaki
# Processing Record 32 of Set 2 | kavieng
# Processing Record 33 of Set 2 | kabalo
# Processing Record 34 of Set 2 | mahebourg
# Processing Record 35 of Set 2 | iranshahr
# Processing Record 36 of Set 2 | saldanha
# Processing Record 37 of Set 2 | alexandria
# Processing Record 38 of Set 2 | palmer
# Processing Record 39 of Set 2 | chuy
# Processing Record 40 of Set 2 | tabou
# Processing Record 41 of Set 2 | erenhot
# Processing Record 42 of Set 2 | palu
# Processing Record 43 of Set 2 | rosetta
# Processing Record 44 of Set 2 | beringovskiy
# Processing Record 45 of Set 2 | nuevo progreso
# Processing Record 46 of Set 2 | yurty
# Processing Record 47 of Set 2 | khatanga
# Processing Record 48 of Set 2 | hobbs
# Processing Record 49 of Set 2 | port elizabeth
# Processing Record 50 of Set 2 | yenagoa
# Processing Record 1 of Set 3 | yerbogachen
# Processing Record 2 of Set 3 | liku
# Processing Record 3 of Set 3 | asheville
# Processing Record 4 of Set 3 | luderitz
# Processing Record 5 of Set 3 | kruisfontein
# Processing Record 6 of Set 3 | barbastro
# Processing Record 7 of Set 3 | braganca
# Processing Record 8 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 9 of Set 3 | arroyo
# Processing Record 10 of Set 3 | bethel
# Processing Record 11 of Set 3 | koumac
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | tuktoyaktuk
# Processing Record 14 of Set 3 | karauzyak
# City not found. Skipping...
# Processing Record 15 of Set 3 | seoul
# Processing Record 16 of Set 3 | lagoa
# Processing Record 17 of Set 3 | mamlyutka
# Processing Record 18 of Set 3 | pevek
# Processing Record 19 of Set 3 | santa maria
# Processing Record 20 of Set 3 | new norfolk
# Processing Record 21 of Set 3 | utica
# Processing Record 22 of Set 3 | coquimbo
# Processing Record 23 of Set 3 | coos bay
# Processing Record 24 of Set 3 | edson
# Processing Record 25 of Set 3 | pangnirtung
# Processing Record 26 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 27 of Set 3 | khuzdar
# Processing Record 28 of Set 3 | batabano
# Processing Record 29 of Set 3 | araouane
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | taoudenni
# Processing Record 32 of Set 3 | qaqortoq
# Processing Record 33 of Set 3 | urmary
# Processing Record 34 of Set 3 | oranjemund
# Processing Record 35 of Set 3 | kodiak
# Processing Record 36 of Set 3 | nizhniy kuranakh
# Processing Record 37 of Set 3 | qaanaaq
# Processing Record 38 of Set 3 | impfondo
# Processing Record 39 of Set 3 | avarua
# Processing Record 40 of Set 3 | ancud
# Processing Record 41 of Set 3 | necochea
# Processing Record 42 of Set 3 | orange walk
# Processing Record 43 of Set 3 | atuona
# Processing Record 44 of Set 3 | bambous virieux
# Processing Record 45 of Set 3 | pathein
# Processing Record 46 of Set 3 | rosarno
# Processing Record 47 of Set 3 | ribeira grande
# Processing Record 48 of Set 3 | cidreira
# Processing Record 49 of Set 3 | upington
# Processing Record 50 of Set 3 | edd
# Processing Record 1 of Set 4 | vrangel
# Processing Record 2 of Set 4 | blairmore
# Processing Record 3 of Set 4 | timizart
# Processing Record 4 of Set 4 | vao
# Processing Record 5 of Set 4 | port-gentil
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | mitu
# Processing Record 8 of Set 4 | butaritari
# Processing Record 9 of Set 4 | comodoro rivadavia
# Processing Record 10 of Set 4 | cape town
# Processing Record 11 of Set 4 | ambon
# Processing Record 12 of Set 4 | nikolskoye
# Processing Record 13 of Set 4 | chunoyar
# Processing Record 14 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 4 | ponta do sol
# Processing Record 16 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | erwitte
# Processing Record 19 of Set 4 | brooks
# Processing Record 20 of Set 4 | fortuna
# Processing Record 21 of Set 4 | cairns
# Processing Record 22 of Set 4 | thanh hoa
# Processing Record 23 of Set 4 | williston
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | bonfim
# Processing Record 26 of Set 4 | belaya gora
# Processing Record 27 of Set 4 | georgetown
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | tuatapere
# Processing Record 30 of Set 4 | valkeakoski
# Processing Record 31 of Set 4 | sao joao da barra
# Processing Record 32 of Set 4 | carnarvon
# Processing Record 33 of Set 4 | wajima
# Processing Record 34 of Set 4 | touros
# Processing Record 35 of Set 4 | lasa
# Processing Record 36 of Set 4 | nelson bay
# Processing Record 37 of Set 4 | naze
# Processing Record 38 of Set 4 | belmonte
# Processing Record 39 of Set 4 | grindavik
# Processing Record 40 of Set 4 | anadyr
# Processing Record 41 of Set 4 | nemuro
# Processing Record 42 of Set 4 | broome
# Processing Record 43 of Set 4 | la trinitaria
# Processing Record 44 of Set 4 | pisco
# Processing Record 45 of Set 4 | komsomolskiy
# Processing Record 46 of Set 4 | hofn
# Processing Record 47 of Set 4 | sitka
# Processing Record 48 of Set 4 | sault sainte marie
# Processing Record 49 of Set 4 | tabas
# Processing Record 50 of Set 4 | vanimo
# Processing Record 1 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 5 | hualmay
# Processing Record 3 of Set 5 | chudniv
# Processing Record 4 of Set 5 | vardo
# Processing Record 5 of Set 5 | sinnamary
# Processing Record 6 of Set 5 | hutchinson
# Processing Record 7 of Set 5 | san andres
# Processing Record 8 of Set 5 | bundaberg
# Processing Record 9 of Set 5 | vung tau
# Processing Record 10 of Set 5 | maragogi
# Processing Record 11 of Set 5 | quatre cocos
# Processing Record 12 of Set 5 | ola
# Processing Record 13 of Set 5 | rio grande
# Processing Record 14 of Set 5 | vanavara
# Processing Record 15 of Set 5 | poum
# Processing Record 16 of Set 5 | sambava
# Processing Record 17 of Set 5 | upernavik
# Processing Record 18 of Set 5 | milkovo
# Processing Record 19 of Set 5 | porto santo
# Processing Record 20 of Set 5 | villanueva de cordoba
# Processing Record 21 of Set 5 | premia de mar
# Processing Record 22 of Set 5 | mackenzie
# Processing Record 23 of Set 5 | arraial do cabo
# Processing Record 24 of Set 5 | bereda
# Processing Record 25 of Set 5 | iqaluit
# Processing Record 26 of Set 5 | acayucan
# Processing Record 27 of Set 5 | wattegama
# Processing Record 28 of Set 5 | waipawa
# Processing Record 29 of Set 5 | taltal
# Processing Record 30 of Set 5 | abu dhabi
# Processing Record 31 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 5 | husavik
# Processing Record 33 of Set 5 | sjovegan
# Processing Record 34 of Set 5 | waddan
# Processing Record 35 of Set 5 | sibolga
# Processing Record 36 of Set 5 | tiksi
# Processing Record 37 of Set 5 | altamira
# Processing Record 38 of Set 5 | samarai
# Processing Record 39 of Set 5 | wamba
# Processing Record 40 of Set 5 | adre
# Processing Record 41 of Set 5 | barrow
# Processing Record 42 of Set 5 | truth or consequences
# Processing Record 43 of Set 5 | kattivakkam
# Processing Record 44 of Set 5 | puerto leguizamo
# Processing Record 45 of Set 5 | barstow
# Processing Record 46 of Set 5 | russell
# Processing Record 47 of Set 5 | do gonbadan
# Processing Record 48 of Set 5 | chulumani
# Processing Record 49 of Set 5 | jacqueville
# Processing Record 50 of Set 5 | golden
# Processing Record 1 of Set 6 | esperance
# Processing Record 2 of Set 6 | lima
# Processing Record 3 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 6 | gilgit
# Processing Record 5 of Set 6 | la ronge
# Processing Record 6 of Set 6 | bisira
# Processing Record 7 of Set 6 | colac
# Processing Record 8 of Set 6 | chokurdakh
# Processing Record 9 of Set 6 | todi
# Processing Record 10 of Set 6 | poso
# Processing Record 11 of Set 6 | agropoli
# Processing Record 12 of Set 6 | omsukchan
# Processing Record 13 of Set 6 | la romana
# Processing Record 14 of Set 6 | matay
# Processing Record 15 of Set 6 | geraldton
# Processing Record 16 of Set 6 | teacapan
# Processing Record 17 of Set 6 | patacamaya
# Processing Record 18 of Set 6 | manadhoo
# Processing Record 19 of Set 6 | teya
# Processing Record 20 of Set 6 | kabanjahe
# Processing Record 21 of Set 6 | san patricio
# Processing Record 22 of Set 6 | rio gallegos
# Processing Record 23 of Set 6 | half moon bay
# Processing Record 24 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 6 | cap malheureux
# Processing Record 26 of Set 6 | los llanos de aridane
# Processing Record 27 of Set 6 | juneau
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | agadir
# Processing Record 30 of Set 6 | hervey bay
# Processing Record 31 of Set 6 | awbari
# Processing Record 32 of Set 6 | akcaabat
# Processing Record 33 of Set 6 | souillac
# Processing Record 34 of Set 6 | constitucion
# Processing Record 35 of Set 6 | roma
# Processing Record 36 of Set 6 | deh rawud
# City not found. Skipping...
# Processing Record 37 of Set 6 | kawambwa
# Processing Record 38 of Set 6 | provideniya
# Processing Record 39 of Set 6 | bay roberts
# Processing Record 40 of Set 6 | marabba
# Processing Record 41 of Set 6 | kyshtovka
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | krasnyy chikoy
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | gejiu
# Processing Record 46 of Set 6 | bathsheba
# Processing Record 47 of Set 6 | erzin
# Processing Record 48 of Set 6 | okha
# Processing Record 49 of Set 6 | namibe
# Processing Record 50 of Set 6 | conceicao da barra
# Processing Record 1 of Set 7 | lata
# Processing Record 2 of Set 7 | nishihara
# Processing Record 3 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 7 | flin flon
# Processing Record 5 of Set 7 | villa rica
# Processing Record 6 of Set 7 | katsuura
# Processing Record 7 of Set 7 | port-cartier
# Processing Record 8 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 7 | rudbar
# Processing Record 10 of Set 7 | charleston
# Processing Record 11 of Set 7 | severo-kurilsk
# Processing Record 12 of Set 7 | salyan
# Processing Record 13 of Set 7 | lerwick
# Processing Record 14 of Set 7 | kondoa
# Processing Record 15 of Set 7 | barbosa ferraz
# Processing Record 16 of Set 7 | harper
# Processing Record 17 of Set 7 | sijunjung
# Processing Record 18 of Set 7 | senneterre
# Processing Record 19 of Set 7 | general roca
# Processing Record 20 of Set 7 | cozumel
# Processing Record 21 of Set 7 | puerto ayacucho
# Processing Record 22 of Set 7 | phonhong
# Processing Record 23 of Set 7 | santiago del estero
# Processing Record 24 of Set 7 | alofi
# Processing Record 25 of Set 7 | viedma
# Processing Record 26 of Set 7 | rabo de peixe
# Processing Record 27 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 28 of Set 7 | bar harbor
# Processing Record 29 of Set 7 | autun
# Processing Record 30 of Set 7 | hendijan
# City not found. Skipping...
# Processing Record 31 of Set 7 | svolvaer
# Processing Record 32 of Set 7 | wencheng
# Processing Record 33 of Set 7 | mutis
# Processing Record 34 of Set 7 | japura
# Processing Record 35 of Set 7 | takoradi
# Processing Record 36 of Set 7 | rudnogorsk
# Processing Record 37 of Set 7 | dandong
# Processing Record 38 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 39 of Set 7 | okhotsk
# Processing Record 40 of Set 7 | sistranda
# Processing Record 41 of Set 7 | copiapo
# Processing Record 42 of Set 7 | port shepstone
# Processing Record 43 of Set 7 | umm lajj
# Processing Record 44 of Set 7 | grand gaube
# Processing Record 45 of Set 7 | ilulissat
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | svetlaya
# Processing Record 48 of Set 7 | numata
# Processing Record 49 of Set 7 | faya
# Processing Record 50 of Set 7 | gibraleon
# Processing Record 1 of Set 8 | lisala
# Processing Record 2 of Set 8 | adrar
# Processing Record 3 of Set 8 | malakisi
# City not found. Skipping...
# Processing Record 4 of Set 8 | rusape
# Processing Record 5 of Set 8 | ahipara
# Processing Record 6 of Set 8 | kieta
# Processing Record 7 of Set 8 | norman wells
# Processing Record 8 of Set 8 | almaty
# Processing Record 9 of Set 8 | kyren
# Processing Record 10 of Set 8 | chimoio
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | vostok
# Processing Record 13 of Set 8 | klaksvik
# Processing Record 14 of Set 8 | port blair
# Processing Record 15 of Set 8 | puerto suarez
# Processing Record 16 of Set 8 | westport
# Processing Record 17 of Set 8 | houma
# Processing Record 18 of Set 8 | boca do acre
# Processing Record 19 of Set 8 | kletnya
# Processing Record 20 of Set 8 | chinhoyi
# Processing Record 21 of Set 8 | bull savanna
# Processing Record 22 of Set 8 | gondanglegi
# Processing Record 23 of Set 8 | sao jose da coroa grande
# Processing Record 24 of Set 8 | colares
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | mizan teferi
# Processing Record 27 of Set 8 | bhayavadar
# Processing Record 28 of Set 8 | margate
# Processing Record 29 of Set 8 | cockburn town
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | pitimbu
# Processing Record 32 of Set 8 | ranong
# Processing Record 33 of Set 8 | tala
# Processing Record 34 of Set 8 | port hedland
# Processing Record 35 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 8 | olga
# Processing Record 37 of Set 8 | fougamou
# Processing Record 38 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 8 | fonte boa
# Processing Record 40 of Set 8 | port lincoln
# Processing Record 41 of Set 8 | campos
# Processing Record 42 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 43 of Set 8 | saint-raphael
# Processing Record 44 of Set 8 | saint anthony
# Processing Record 45 of Set 8 | nattarasankottai
# Processing Record 46 of Set 8 | witrivier
# City not found. Skipping...
# Processing Record 47 of Set 8 | ayan
# Processing Record 48 of Set 8 | emba
# Processing Record 49 of Set 8 | qiryat shemona
# Processing Record 50 of Set 8 | banda aceh
# Processing Record 1 of Set 9 | murray bridge
# Processing Record 2 of Set 9 | nouadhibou
# Processing Record 3 of Set 9 | loukhi
# Processing Record 4 of Set 9 | ovruch
# Processing Record 5 of Set 9 | dublin
# Processing Record 6 of Set 9 | oyama
# Processing Record 7 of Set 9 | yar-sale
# Processing Record 8 of Set 9 | aklavik
# Processing Record 9 of Set 9 | bombay
# Processing Record 10 of Set 9 | palauig
# Processing Record 11 of Set 9 | kanniyakumari
# Processing Record 12 of Set 9 | abay
# Processing Record 13 of Set 9 | chertkovo
# Processing Record 14 of Set 9 | kahului
# Processing Record 15 of Set 9 | matam
# Processing Record 16 of Set 9 | boden
# Processing Record 17 of Set 9 | kizilskoye
# Processing Record 18 of Set 9 | visimo-utkinsk
# City not found. Skipping...
# Processing Record 19 of Set 9 | castro alves
# Processing Record 20 of Set 9 | neuquen
# Processing Record 21 of Set 9 | pogranichnyy
# Processing Record 22 of Set 9 | isangel
# Processing Record 23 of Set 9 | victoria
# Processing Record 24 of Set 9 | harlingen
# Processing Record 25 of Set 9 | haverfordwest
# Processing Record 26 of Set 9 | jumla
# Processing Record 27 of Set 9 | beian
# Processing Record 28 of Set 9 | the valley
# Processing Record 29 of Set 9 | fairbanks
# Processing Record 30 of Set 9 | angra
# City not found. Skipping...
# Processing Record 31 of Set 9 | ritchie
# Processing Record 32 of Set 9 | ballina
# Processing Record 33 of Set 9 | pori
# Processing Record 34 of Set 9 | orsha
# Processing Record 35 of Set 9 | kemijarvi
# Processing Record 36 of Set 9 | mbanza-ngungu
# Processing Record 37 of Set 9 | semey
# Processing Record 38 of Set 9 | muisne
# Processing Record 39 of Set 9 | leshukonskoye
# Processing Record 40 of Set 9 | kavaratti
# Processing Record 41 of Set 9 | assela
# City not found. Skipping...
# Processing Record 42 of Set 9 | lethem
# Processing Record 43 of Set 9 | beyneu
# Processing Record 44 of Set 9 | tomatlan
# Processing Record 45 of Set 9 | canico
# Processing Record 46 of Set 9 | egvekinot
# Processing Record 47 of Set 9 | cukai
# Processing Record 48 of Set 9 | kaele
# Processing Record 49 of Set 9 | pedra azul
# Processing Record 50 of Set 9 | aginskoye
# Processing Record 1 of Set 10 | manicore
# Processing Record 2 of Set 10 | biak
# Processing Record 3 of Set 10 | san rafael
# Processing Record 4 of Set 10 | luanda
# Processing Record 5 of Set 10 | macamic
# Processing Record 6 of Set 10 | hay river
# Processing Record 7 of Set 10 | humaita
# Processing Record 8 of Set 10 | burica
# City not found. Skipping...
# Processing Record 9 of Set 10 | bac lieu
# Processing Record 10 of Set 10 | novoagansk
# Processing Record 11 of Set 10 | zhangjiakou
# Processing Record 12 of Set 10 | flagstaff
# Processing Record 13 of Set 10 | ketchikan
# Processing Record 14 of Set 10 | casablanca
# Processing Record 15 of Set 10 | marawi
# Processing Record 16 of Set 10 | dingle
# Processing Record 17 of Set 10 | san policarpo
# Processing Record 18 of Set 10 | umm kaddadah
# Processing Record 19 of Set 10 | padang
# Processing Record 20 of Set 10 | san cristobal
# Processing Record 21 of Set 10 | qasigiannguit
# Processing Record 22 of Set 10 | richards bay
# Processing Record 23 of Set 10 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 10 | shuyskoye
# Processing Record 25 of Set 10 | zhuhai
# Processing Record 26 of Set 10 | pamekasan
# Processing Record 27 of Set 10 | constantine
# Processing Record 28 of Set 10 | poya
# Processing Record 29 of Set 10 | maniitsoq
# Processing Record 30 of Set 10 | terrell
# Processing Record 31 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 32 of Set 10 | horki
# Processing Record 33 of Set 10 | batemans bay
# Processing Record 34 of Set 10 | ahuimanu
# Processing Record 35 of Set 10 | vahan
# Processing Record 36 of Set 10 | turbat
# Processing Record 37 of Set 10 | los chiles
# Processing Record 38 of Set 10 | palmerston
# Processing Record 39 of Set 10 | honningsvag
# Processing Record 40 of Set 10 | bandarbeyla
# Processing Record 41 of Set 10 | hirara
# Processing Record 42 of Set 10 | asfi
# Processing Record 43 of Set 10 | kathmandu
# Processing Record 44 of Set 10 | newala
# Processing Record 45 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 46 of Set 10 | don sak
# Processing Record 47 of Set 10 | aksarka
# Processing Record 48 of Set 10 | turochak
# Processing Record 49 of Set 10 | nchelenge
# Processing Record 50 of Set 10 | victor harbor
# Processing Record 1 of Set 11 | lamar
# Processing Record 2 of Set 11 | abonnema
# Processing Record 3 of Set 11 | yicheng
# Processing Record 4 of Set 11 | sakakah
# Processing Record 5 of Set 11 | celestun
# Processing Record 6 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 11 | aleksandrov gay
# Processing Record 8 of Set 11 | sampit
# Processing Record 9 of Set 11 | haines junction
# Processing Record 10 of Set 11 | kununurra
# Processing Record 11 of Set 11 | jining
# Processing Record 12 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 11 | chapada dos guimaraes
# Processing Record 14 of Set 11 | eureka
# Processing Record 15 of Set 11 | athabasca
# Processing Record 16 of Set 11 | barra dos coqueiros
# Processing Record 17 of Set 11 | hami
# Processing Record 18 of Set 11 | tuy hoa
# Processing Record 19 of Set 11 | nuuk
# Processing Record 20 of Set 11 | airai
# Processing Record 21 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 11 | faanui
# Processing Record 23 of Set 11 | kuah
# Processing Record 24 of Set 11 | surt
# Processing Record 25 of Set 11 | taybad
# Processing Record 26 of Set 11 | lodja
# Processing Record 27 of Set 11 | lingao
# Processing Record 28 of Set 11 | malaya serdoba
# Processing Record 29 of Set 11 | balykshi
# Processing Record 30 of Set 11 | albenga
# Processing Record 31 of Set 11 | salinopolis
# Processing Record 32 of Set 11 | manaure
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | tiznit
# Processing Record 35 of Set 11 | kazachinskoye
# Processing Record 36 of Set 11 | safaga
# Processing Record 37 of Set 11 | neiafu
# Processing Record 38 of Set 11 | talara
# Processing Record 39 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 40 of Set 11 | port hawkesbury
# Processing Record 41 of Set 11 | jakar
# Processing Record 42 of Set 11 | roald
# Processing Record 43 of Set 11 | veraval
# Processing Record 44 of Set 11 | porto novo
# Processing Record 45 of Set 11 | muros
# Processing Record 46 of Set 11 | mbandaka
# Processing Record 47 of Set 11 | winnemucca
# Processing Record 48 of Set 11 | belyy yar
# Processing Record 49 of Set 11 | deputatskiy
# Processing Record 50 of Set 11 | san angelo
# Processing Record 1 of Set 12 | linda
# Processing Record 2 of Set 12 | rasht
# Processing Record 3 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 12 | buluang
# Processing Record 5 of Set 12 | arlit
# Processing Record 6 of Set 12 | coahuayana
# Processing Record 7 of Set 12 | orlik
# Processing Record 8 of Set 12 | lakes entrance
# Processing Record 9 of Set 12 | tautira
# Processing Record 10 of Set 12 | chippewa falls
# Processing Record 11 of Set 12 | tukrah
# Processing Record 12 of Set 12 | kijang
# Processing Record 13 of Set 12 | ust-maya
# Processing Record 14 of Set 12 | san quintin
# Processing Record 15 of Set 12 | khandyga
# Processing Record 16 of Set 12 | khormuj
# City not found. Skipping...
# Processing Record 17 of Set 12 | alyangula
# Processing Record 18 of Set 12 | medina del campo
# Processing Record 19 of Set 12 | kushiro
# Processing Record 20 of Set 12 | akyab
# Processing Record 21 of Set 12 | huadian
# Processing Record 22 of Set 12 | zaraysk
# Processing Record 23 of Set 12 | whitehorse
# Processing Record 24 of Set 12 | lashio
# Processing Record 25 of Set 12 | tenenkou
# Processing Record 26 of Set 12 | shieli
# Processing Record 27 of Set 12 | khorixas
# Processing Record 28 of Set 12 | goderich
# Processing Record 29 of Set 12 | ulaanbaatar
# Processing Record 30 of Set 12 | cap-aux-meules
# Processing Record 31 of Set 12 | shelburne
# Processing Record 32 of Set 12 | kodinsk
# Processing Record 33 of Set 12 | bozhou
# Processing Record 34 of Set 12 | vereshchagino
# Processing Record 35 of Set 12 | oistins
# Processing Record 36 of Set 12 | uberlandia
# Processing Record 37 of Set 12 | springbok
# Processing Record 38 of Set 12 | bubaque
# Processing Record 39 of Set 12 | severnoye
# Processing Record 40 of Set 12 | xinzhi
# Processing Record 41 of Set 12 | imbituba
# Processing Record 42 of Set 12 | maues
# Processing Record 43 of Set 12 | bavleny
# Processing Record 44 of Set 12 | harindanga
# Processing Record 45 of Set 12 | xingcheng
# Processing Record 46 of Set 12 | marienburg
# Processing Record 47 of Set 12 | cayenne
# Processing Record 48 of Set 12 | khasan
# Processing Record 49 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 12 | zhezkazgan
# Processing Record 1 of Set 13 | akhmim
# Processing Record 2 of Set 13 | north platte
# Processing Record 3 of Set 13 | torbay
# Processing Record 4 of Set 13 | matagami
# Processing Record 5 of Set 13 | emerald
# Processing Record 6 of Set 13 | cabra
# Processing Record 7 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 8 of Set 13 | nouakchott
# Processing Record 9 of Set 13 | yarim
# Processing Record 10 of Set 13 | port moresby
# Processing Record 11 of Set 13 | domoni
# Processing Record 12 of Set 13 | plettenberg bay
# Processing Record 13 of Set 13 | kosa
# Processing Record 14 of Set 13 | marsa matruh
# Processing Record 15 of Set 13 | port macquarie
# Processing Record 16 of Set 13 | telhara
# Processing Record 17 of Set 13 | tineo
# Processing Record 18 of Set 13 | teguldet
# Processing Record 19 of Set 13 | fuling
# Processing Record 20 of Set 13 | saint-pierre
# Processing Record 21 of Set 13 | sorland
# Processing Record 22 of Set 13 | alizai
# Processing Record 23 of Set 13 | san carlos
# Processing Record 24 of Set 13 | erzincan
# Processing Record 25 of Set 13 | santa fe
# Processing Record 26 of Set 13 | jeremie
# Processing Record 27 of Set 13 | kambove
# Processing Record 28 of Set 13 | merrill
# Processing Record 29 of Set 13 | hilton head island
# Processing Record 30 of Set 13 | soyo
# Processing Record 31 of Set 13 | camalu
# Processing Record 32 of Set 13 | ihlow
# Processing Record 33 of Set 13 | maunabo
# Processing Record 34 of Set 13 | bayshore gardens
# Processing Record 35 of Set 13 | inuvik
# Processing Record 36 of Set 13 | cuyo
# Processing Record 37 of Set 13 | kudahuvadhoo
# Processing Record 38 of Set 13 | novyy urengoy
# Processing Record 39 of Set 13 | sainte-maxime
# Processing Record 40 of Set 13 | mbigou
# Processing Record 41 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 42 of Set 13 | jaisinghnagar
# Processing Record 43 of Set 13 | vanderhoof
# Processing Record 44 of Set 13 | kamen-rybolov
# Processing Record 45 of Set 13 | rongcheng
# Processing Record 46 of Set 13 | farafangana
# Processing Record 47 of Set 13 | camacha
# Processing Record 48 of Set 13 | saint-francois
# Processing Record 49 of Set 13 | yulara
# Processing Record 50 of Set 13 | baykit
# Processing Record 1 of Set 14 | sao domingos
# Processing Record 2 of Set 14 | mutoko
# Processing Record 3 of Set 14 | sharjah
# Processing Record 4 of Set 14 | chagda
# City not found. Skipping...
# Processing Record 5 of Set 14 | havre
# Processing Record 6 of Set 14 | itaguai
# Processing Record 7 of Set 14 | vitry-le-francois
# Processing Record 8 of Set 14 | grand baie
# Processing Record 9 of Set 14 | gao
# Processing Record 10 of Set 14 | cartagena del chaira
# Processing Record 11 of Set 14 | tawnat
# City not found. Skipping...
# Processing Record 12 of Set 14 | sambo creek
# Processing Record 13 of Set 14 | acapulco
# Processing Record 14 of Set 14 | deloraine
# Processing Record 15 of Set 14 | nador
# Processing Record 16 of Set 14 | kamenka
# Processing Record 17 of Set 14 | bikaner
# Processing Record 18 of Set 14 | lemesos
# City not found. Skipping...
# Processing Record 19 of Set 14 | yakeshi
# Processing Record 20 of Set 14 | bocaiuva
# Processing Record 21 of Set 14 | saint-louis
# Processing Record 22 of Set 14 | mount isa
# Processing Record 23 of Set 14 | lavrentiya
# Processing Record 24 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 14 | karratha
# Processing Record 26 of Set 14 | kimbe
# Processing Record 27 of Set 14 | villamontes
# Processing Record 28 of Set 14 | kiblawan
# Processing Record 29 of Set 14 | odweyne
# Processing Record 30 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 31 of Set 14 | jinchang
# Processing Record 32 of Set 14 | kapit
# Processing Record 33 of Set 14 | mount pleasant
# Processing Record 34 of Set 14 | francisco beltrao
# Processing Record 35 of Set 14 | zemio
# Processing Record 36 of Set 14 | ko samui
# Processing Record 37 of Set 14 | sovetskiy
# Processing Record 38 of Set 14 | bagdarin
# Processing Record 39 of Set 14 | xingyi
# Processing Record 40 of Set 14 | shakhunya
# Processing Record 41 of Set 14 | gwanda
# Processing Record 42 of Set 14 | lahaina
# Processing Record 43 of Set 14 | uvat
# Processing Record 44 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 45 of Set 14 | sangar
# Processing Record 46 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 14 | westpunt
# City not found. Skipping...
# Processing Record 48 of Set 14 | zhigansk
# Processing Record 49 of Set 14 | zabol
# Processing Record 50 of Set 14 | altay
# Processing Record 1 of Set 15 | mayo
# Processing Record 2 of Set 15 | chicama
# Processing Record 3 of Set 15 | berlevag
# Processing Record 4 of Set 15 | chaa-khol
# City not found. Skipping...
# Processing Record 5 of Set 15 | morondava
# Processing Record 6 of Set 15 | hof
# Processing Record 7 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 8 of Set 15 | karakendzha
# City not found. Skipping...
# Processing Record 9 of Set 15 | bargal
# City not found. Skipping...
# Processing Record 10 of Set 15 | lorengau
# Processing Record 11 of Set 15 | beloha
# Processing Record 12 of Set 15 | balaguer
# Processing Record 13 of Set 15 | koutsouras
# Processing Record 14 of Set 15 | nantucket
# Processing Record 15 of Set 15 | wewak
# Processing Record 16 of Set 15 | lucea
# Processing Record 17 of Set 15 | mandurah
# Processing Record 18 of Set 15 | chapais
# Processing Record 19 of Set 15 | asau
# Processing Record 20 of Set 15 | plouzane
# Processing Record 21 of Set 15 | eyl
# Processing Record 22 of Set 15 | ramkola
# Processing Record 23 of Set 15 | kande
# Processing Record 24 of Set 15 | mancora
# Processing Record 25 of Set 15 | novopetrovskoye
# Processing Record 26 of Set 15 | sisimiut
# Processing Record 27 of Set 15 | mitchell
# Processing Record 28 of Set 15 | pacifica
# Processing Record 29 of Set 15 | santa rosa
# Processing Record 30 of Set 15 | ulladulla
# Processing Record 31 of Set 15 | byron bay
# Processing Record 32 of Set 15 | mareeba
# Processing Record 33 of Set 15 | basco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Rikitea -23.1203 -134.9692     76.73        74          11
# 1    Solnechnyy  50.7214  136.6319     12.67        95         100
# 2        Castro -24.7911  -50.0119     75.43        60          85
# 3        Albany  42.6001  -73.9662     30.85        84          91
# 4      Hermanus -34.4187   19.2345     63.55        84          75
# ..          ...      ...       ...       ...       ...         ...
# 673  Santa Rosa  14.3122  121.1114     77.09        88         100
# 674   Ulladulla -35.3500  150.4667     60.57        65          88
# 675   Byron Bay -28.6500  153.6167     71.55        83          93
# 676     Mareeba -17.0000  145.4333     72.32        85          33
# 677       Basco  20.4487  121.9702     78.31        85          99
#
#      Wind Speed Country Current Description
# 0         16.35      PF          few clouds
# 1          3.18      RU          light snow
# 2          3.74      BR     overcast clouds
# 3          2.98      US     overcast clouds
# 4          7.61      ZA       broken clouds
# ..          ...     ...                 ...
# 673        6.38      PH     overcast clouds
# 674        3.42      AU     overcast clouds
# 675        9.26      AU     overcast clouds
# 676        3.15      AU    scattered clouds
# 677       26.84      PH          light rain
#
# [678 rows x 9 columns]

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                    City Country      Lat       Lng  Max Temp  Humidity  \
# 0               Rikitea      PF -23.1203 -134.9692     76.73        74
# 1            Solnechnyy      RU  50.7214  136.6319     12.67        95
# 2                Castro      BR -24.7911  -50.0119     75.43        60
# 3                Albany      US  42.6001  -73.9662     30.85        84
# 4              Hermanus      ZA -34.4187   19.2345     63.55        84
# 5        Saint-Augustin      CA  51.2260  -58.6502     34.32        84
# 6  Vila Franca Do Campo      PT  37.7167  -25.4333     59.41        67
# 7            Sao Filipe      CV  14.8961  -24.4956     76.80        70
# 8               Guozhen      CN  34.3659  107.3590     41.00        54
# 9              Meulaboh      ID   4.1363   96.1285     74.34        91
#
#    Cloudiness  Wind Speed Current Description
# 0          11       16.35          few clouds
# 1         100        3.18          light snow
# 2          85        3.74     overcast clouds
# 3          91        2.98     overcast clouds
# 4          75        7.61       broken clouds
# 5          99       23.71     overcast clouds
# 6          95        4.90     overcast clouds
# 7          95       14.70     overcast clouds
# 8         100        8.16     overcast clouds
# 9         100        4.52       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
